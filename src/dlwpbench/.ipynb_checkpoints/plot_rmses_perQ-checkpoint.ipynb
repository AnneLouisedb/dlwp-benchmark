# %%
import xarray as xr


p = '/projects/prjs1254/outputs/UNETHPX32/PDErefhpx321240/evaluation/outputs.nc'

p = '/projects/prjs1254/outputs/UNETHPX32/PDErefhpx321240/evaluation/targets.nc'


# load the outputs
# split both in quaters of the year e.g. Q1, Q2 etc
